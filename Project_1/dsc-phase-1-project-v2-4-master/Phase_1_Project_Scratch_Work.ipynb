# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import string
punctuation = string.punctuation

conn = sqlite3.connect("zippedData/im.db")

# %% [markdown]
# A key measure of success for any movie is the amount of profit it brings in for its studio. None of our datasets include profit, so we will begin by determining how profitable each movie in our dataset is.

# %%
# need a column that denotes profit, so start by importing financial data
movie_finances = pd.read_csv('zippedData/tn.movie_budgets.csv')
movie_finances.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# check data types of seres in movie_finances
movie_finances.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
# financial information is currently stored as a string, need to convert to integer
# start by stripping '$' from each string
movie_finances['production_budget'] = movie_finances['production_budget'].apply(lambda x: x.replace('$', ""))
movie_finances['domestic_gross'] = movie_finances['domestic_gross'].apply(lambda x: x.replace('$', ""))
movie_finances['worldwide_gross'] = movie_finances['worldwide_gross'].apply(lambda x: x.replace('$', ""))

# %%
# then strip ',' from each string
movie_finances['production_budget'] = movie_finances['production_budget'].apply(lambda x: x.replace(',', ""))
movie_finances['domestic_gross'] = movie_finances['domestic_gross'].apply(lambda x: x.replace(',', ""))
movie_finances['worldwide_gross'] = movie_finances['worldwide_gross'].apply(lambda x: x.replace(',', ""))

# %%
# finally, change dtype to int
movie_finances['production_budget'] = movie_finances['production_budget'].astype(int)
movie_finances['domestic_gross'] = movie_finances['domestic_gross'].astype(int)
movie_finances['worldwide_gross'] = movie_finances['worldwide_gross'].astype(int)

# %%
# confirm dtypes have been updated
movie_finances.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# dtype: object

# %% [markdown]
# Now that we have cleaned the dataset, we can determine the domestic and worldwide profit for each movie. We will do so by subtracting the production budget from the domestic gross to determine domestic profit, and the from worldwide gross to determine worldwide profit.

# %%
# calculate domestic profit and save in a new column
movie_finances['domestic_profit'] = movie_finances['domestic_gross'] - movie_finances['production_budget']

# calculate worldwide profit and save in a new column
movie_finances['worldwide_profit'] = movie_finances['worldwide_gross'] - movie_finances['production_budget']

movie_finances
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 0             425000000       760507625       2776345279        335507625
# 1             410600000       241063875       1045663875       -169536125
# 2             350000000        42762350        149762350       -307237650
# 3             330600000       459005868       1403013963        128405868
# 4             317000000       620181382       1316721747        303181382
# ...                 ...             ...              ...              ...
# 5777               7000               0                0            -7000
# 5778               6000           48482           240495            42482
# 5779               5000            1338             1338            -3662
# 5780               1400               0                0            -1400
# 5781               1100          181041           181041           179941
#
#       worldwide_profit
# 0           2351345279
# 1            635063875
# 2           -200237650
# 3           1072413963
# 4            999721747
# ...                ...
# 5777             -7000
# 5778            234495
# 5779             -3662
# 5780             -1400
# 5781            179941
#
# [5782 rows x 8 columns]

# %% [markdown]
# ### What movie rating should Microsoft aim for?
# In addition to identifying ___ and ___, the rating a movie receives

# %%
# get writer info from im.db writers table
writers = pd.read_sql("""
SELECT *
  FROM writers
  
""", conn)

# %%
# get director info from im.db directors table
directors = pd.read_sql("""
SELECT *
  FROM directors
""", conn)

# %%
# get information from im.db persons table
names = pd.read_sql('''
SELECT * 
FROM persons
''', conn)

# %%
# print column names to identify information to merge on
print(directors.columns)
print(names.columns)
print(writers.columns)
# Out:
# Index(['movie_id', 'person_id'], dtype='object')
# Index(['person_id', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession'],
#       dtype='object')
# Index(['movie_id', 'person_id'], dtype='object')

# %%
# merge directors and names to obtain director names as "primary_name"
director_names = pd.merge(directors, names , how = 'inner', on = 'person_id')
director_names
# Out:
#          movie_id   person_id          primary_name  birth_year  death_year  \
# 0       tt0285252   nm0899854           Tony Vitale      1964.0         NaN
# 1       tt0462036   nm1940585            Bill Haley         NaN         NaN
# 2       tt0835418   nm0151540     Jay Chandrasekhar      1968.0         NaN
# 3       tt0835418   nm0151540     Jay Chandrasekhar      1968.0         NaN
# 4       tt0859635   nm0151540     Jay Chandrasekhar      1968.0         NaN
# ...           ...         ...                   ...         ...         ...
# 291166  tt8999892  nm10122247       C. Damon Adcock         NaN         NaN
# 291167  tt8999974  nm10122357         Daysi Burbano         NaN         NaN
# 291168  tt9001390   nm6711477         Bernard Lessa         NaN         NaN
# 291169  tt9001494  nm10123242             Tate Nova         NaN         NaN
# 291170  tt9001494  nm10123248  Courtney Faye Powell         NaN         NaN
#
#                      primary_profession
# 0              producer,director,writer
# 1              director,writer,producer
# 2                 director,actor,writer
# 3                 director,actor,writer
# 4                 director,actor,writer
# ...                                 ...
# 291166                             None
# 291167  director,writer,cinematographer
# 291168  director,writer,cinematographer
# 291169                director,producer
# 291170                director,producer
#
# [291171 rows x 6 columns]

# %%
# merge writers and names to obtain writer names as "primary_name"
writer_names = pd.merge(writers, names , how = 'inner', on = 'person_id')
writer_names
# Out:
#          movie_id   person_id        primary_name  birth_year  death_year  \
# 0       tt0285252   nm0899854         Tony Vitale      1964.0         NaN
# 1       tt0438973   nm0175726        Steve Conrad      1968.0         NaN
# 2       tt2358925   nm0175726        Steve Conrad      1968.0         NaN
# 3       tt2543472   nm0175726        Steve Conrad      1968.0         NaN
# 4       tt0359950   nm0175726        Steve Conrad      1968.0         NaN
# ...           ...         ...                 ...         ...         ...
# 255866  tt8999892  nm10122247     C. Damon Adcock         NaN         NaN
# 255867  tt8999892  nm10122246   Bradley T. Castle         NaN         NaN
# 255868  tt8999974  nm10122357       Daysi Burbano         NaN         NaN
# 255869  tt9001390   nm6711477       Bernard Lessa         NaN         NaN
# 255870  tt9010172   nm8352242  Vibol S. Sungkriem         NaN         NaN
#
#                      primary_profession
# 0              producer,director,writer
# 1              writer,producer,director
# 2              writer,producer,director
# 3              writer,producer,director
# 4              writer,producer,director
# ...                                 ...
# 255866                             None
# 255867            actor,writer,producer
# 255868  director,writer,cinematographer
# 255869  director,writer,cinematographer
# 255870         producer,writer,director
#
# [255871 rows x 6 columns]

# %%
# create a merged dataframe with writers and directors for each movie
directors_writers = pd.merge(director_names, writer_names, how = 'inner', on = 'movie_id').drop_duplicates().reset_index()

# %%
# drop extraneous columns
directors_writers.drop(['birth_year_x', 'death_year_x', 'primary_profession_x', 
                       'birth_year_y', 'death_year_y', 'primary_profession_y'],
                      axis = 1, inplace = True)

# %%
# rename columns to be clearer
directors_writers.rename(columns = {'person_id_x': 'director_id',
                                   'primary_name_x': 'director_name',
                                   'person_id_y': 'writer_id',
                                   'primary_name_y': 'writer_name'},
                        inplace = True)
directors_writers
# Out:
#            index   movie_id director_id      director_name   writer_id  \
# 0              0  tt0285252   nm0899854        Tony Vitale   nm0899854
# 1              1  tt0462036   nm1940585         Bill Haley   nm1940585
# 2              2  tt0835418   nm0151540  Jay Chandrasekhar   nm0310087
# 3              3  tt0835418   nm0151540  Jay Chandrasekhar   nm0841532
# 4              6  tt0859635   nm0151540  Jay Chandrasekhar   nm0151540
# ...          ...        ...         ...                ...         ...
# 254148  48154512  tt8998302  nm10121510        Daryl Boman  nm10121510
# 254149  48154513  tt8999892  nm10122247    C. Damon Adcock  nm10122247
# 254150  48154514  tt8999892  nm10122247    C. Damon Adcock  nm10122246
# 254151  48154517  tt8999974  nm10122357      Daysi Burbano  nm10122357
# 254152  48154518  tt9001390   nm6711477      Bernard Lessa   nm6711477
#
#               writer_name
# 0             Tony Vitale
# 1              Bill Haley
# 2            Peter Gaulke
# 3           Gerry Swallow
# 4       Jay Chandrasekhar
# ...                   ...
# 254148        Daryl Boman
# 254149    C. Damon Adcock
# 254150  Bradley T. Castle
# 254151      Daysi Burbano
# 254152      Bernard Lessa
#
# [254153 rows x 6 columns]

# %%
# get information on movie ratings from file
movie_ratings = pd.read_table('zippedData/rt.movie_info.tsv', encoding = 'latin1')
movie_ratings
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
# common columns across both dataframes are director and writer
# will need to create a column that combines those names to merge the dataframes

directors_writers['director_writer'] = directors_writers['director_name'] + ", " + directors_writers['writer_name']
movie_ratings['director_writer'] = movie_ratings['director'] + ", " + movie_ratings['writer']

# %%
movie_ratings
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio  \
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
#                                         director_writer
# 0                      William Friedkin, Ernest Tidyman
# 1        David Cronenberg, David Cronenberg|Don DeLillo
# 2                        Allison Anders, Allison Anders
# 3       Barry Levinson, Paul Attanasio|Michael Crichton
# 4                          Rodney Bennett, Giles Cooper
# ...                                                 ...
# 1555                                                NaN
# 1556  Steve Barron, Terry Turner|Tom Davis|Dan Aykro...
# 1557                                                NaN
# 1558  David Mickey Evans, David Mickey Evans|Robert ...
# 1559                                                NaN
#
# [1560 rows x 13 columns]

# %%
# merge dataframes
movies = pd.merge(directors_writers, movie_ratings, how = 'inner', on = 'director_writer').drop_duplicates().reset_index()
movies
# Out:
#      level_0     index   movie_id director_id          director_name  \
# 0          0       290  tt1125929   nm0000431        Taylor Hackford
# 1          1     33264  tt2693702   nm0000419        Jean-Luc Godard
# 2          2  40132965  tt2400275   nm0000419        Jean-Luc Godard
# 3          3  40132966  tt1438535   nm0000419        Jean-Luc Godard
# 4          4  40133087  tt5749596   nm0000419        Jean-Luc Godard
# ..       ...       ...        ...         ...                    ...
# 495      495  48113936  tt5536610   nm0420982         Tamara Jenkins
# 496      496  48122334  tt5873216   nm4354445  Anahita Ghazvinizadeh
# 497      497  48150588  tt0376479   nm0000191          Ewan McGregor
# 498      498  48151041  tt1720616   nm0922724     Jennifer Westfeldt
# 499      499  48152447  tt3317208   nm0625789       Tim Blake Nelson
#
#      writer_id            writer_name  \
# 0    nm0414893          Mark Jacobson
# 1    nm0000419        Jean-Luc Godard
# 2    nm0000419        Jean-Luc Godard
# 3    nm0000419        Jean-Luc Godard
# 4    nm0000419        Jean-Luc Godard
# ..         ...                    ...
# 495  nm0420982         Tamara Jenkins
# 496  nm4354445  Anahita Ghazvinizadeh
# 497  nm0738908            John Romano
# 498  nm0922724     Jennifer Westfeldt
# 499  nm0625789       Tim Blake Nelson
#
#                                   director_writer    id  \
# 0                  Taylor Hackford, Mark Jacobson    14
# 1                Jean-Luc Godard, Jean-Luc Godard   691
# 2                Jean-Luc Godard, Jean-Luc Godard   691
# 3                Jean-Luc Godard, Jean-Luc Godard   691
# 4                Jean-Luc Godard, Jean-Luc Godard   691
# ..                                            ...   ...
# 495                Tamara Jenkins, Tamara Jenkins   528
# 496  Anahita Ghazvinizadeh, Anahita Ghazvinizadeh  1714
# 497                    Ewan McGregor, John Romano  1236
# 498        Jennifer Westfeldt, Jennifer Westfeldt   304
# 499            Tim Blake Nelson, Tim Blake Nelson  1300
#
#                                               synopsis rating  \
# 0    "Love Ranch" is a bittersweet love story that ...      R
# 1    Director Jean-Luc Godard tries to remain objec...     NR
# 2    Director Jean-Luc Godard tries to remain objec...     NR
# 3    Director Jean-Luc Godard tries to remain objec...     NR
# 4    Director Jean-Luc Godard tries to remain objec...     NR
# ..                                                 ...    ...
# 495  The last thing the two Savage siblings ever wa...      R
# 496  Through the prism of J, notions of in-between-...     NR
# 497  AMERICAN PASTORAL follows Seymour "Swede" Levo...      R
# 498  Friends with Kids is a daring and poignant ens...      R
# 499  The story of five prisoners in the Auschwitz c...      R
#
#                                  genre               director  \
# 0                                Drama        Taylor Hackford
# 1    Art House and International|Drama        Jean-Luc Godard
# 2    Art House and International|Drama        Jean-Luc Godard
# 3    Art House and International|Drama        Jean-Luc Godard
# 4    Art House and International|Drama        Jean-Luc Godard
# ..                                 ...                    ...
# 495                       Comedy|Drama         Tamara Jenkins
# 496                              Drama  Anahita Ghazvinizadeh
# 497                              Drama          Ewan McGregor
# 498                       Comedy|Drama     Jennifer Westfeldt
# 499                              Drama       Tim Blake Nelson
#
#                     writer  theater_date      dvd_date currency box_office  \
# 0            Mark Jacobson  Jun 30, 2010   Nov 9, 2010        $    134,904
# 1          Jean-Luc Godard  Sep 20, 1962  Aug 11, 1998      NaN        NaN
# 2          Jean-Luc Godard  Sep 20, 1962  Aug 11, 1998      NaN        NaN
# 3          Jean-Luc Godard  Sep 20, 1962  Aug 11, 1998      NaN        NaN
# 4          Jean-Luc Godard  Sep 20, 1962  Aug 11, 1998      NaN        NaN
# ..                     ...           ...           ...      ...        ...
# 495         Tamara Jenkins  Nov 28, 2007  Apr 22, 2008        $  6,426,953
# 496  Anahita Ghazvinizadeh           NaN           NaN      NaN        NaN
# 497            John Romano  Oct 21, 2016   Feb 7, 2017        $    541,457
# 498     Jennifer Westfeldt   Mar 9, 2012  Jul 17, 2012        $  5,600,000
# 499       Tim Blake Nelson  Oct 25, 2002  Mar 18, 2003      NaN        NaN
#
#          runtime                    studio
# 0    117 minutes                       NaN
# 1     85 minutes                       NaN
# 2     85 minutes                       NaN
# 3     85 minutes                       NaN
# 4     85 minutes                       NaN
# ..           ...                       ...
# 495  114 minutes  Fox Searchlight Pictures
# 496   80 minutes                       NaN
# 497  126 minutes   Lakeshore Entertainment
# 498  107 minutes      Roadside Attractions
# 499  108 minutes          Lions Gate Films
#
# [500 rows x 20 columns]

# %%
movies['rating'].value_counts()
# Out:
# R        205
# NR       141
# PG-13     78
# PG        69
# G          6
# NC17       1
# Name: rating, dtype: int64

# %%
basics = pd.read_sql("""
SELECT primary_title, runtime_minutes, genres
  FROM movie_basics
""", conn)

basics
# Out:
#                                       primary_title  runtime_minutes  \
# 0                                         Sunghursh            175.0
# 1                   One Day Before the Rainy Season            114.0
# 2                        The Other Side of the Wind            122.0
# 3                                   Sabse Bada Sukh              NaN
# 4                          The Wandering Soap Opera             80.0
# ...                                             ...              ...
# 146139                          Kuambil Lagi Hatiku            123.0
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro              NaN
# 146141                              Dankyavar Danka              NaN
# 146142                                       6 Gunn            116.0
# 146143               Chico Albuquerque - Revelações              NaN
#
#                       genres
# 0         Action,Crime,Drama
# 1            Biography,Drama
# 2                      Drama
# 3               Comedy,Drama
# 4       Comedy,Drama,Fantasy
# ...                      ...
# 146139                 Drama
# 146140           Documentary
# 146141                Comedy
# 146142                  None
# 146143           Documentary
#
# [146144 rows x 3 columns]
